# %% [markdown]
# ---
# title: "These Strange New Minds: LLM Mind and Conscious"
# description: "Diving into Chapters 15 - 18"
# author: "Lindsey Lee"
# date: "11/30/2025"
# categories:
#   - LLMs
#   - Book
# ---

# %% [markdown]
# ---
#
# ![music miffy.png](attachment:676fe7fc-598d-4ccd-87b0-19b57e8bfed5.png)

# %% [markdown]
# ---
#
# ### Reflection
#
# This book is only getting more and more interesting! Chapter 15 opens up Part 3 of the book,
