# %% [markdown]
# ---
# title: "Experimenting with OpenEvidence"
# description: "How reliable and effective is OpenEvidence as a source for healthcare information?"
# author: "Lindsey Lee"
# date: "12/8/2025"
# categories:
#   - LLMs
#   - Healthcare
#   - Prompting
# ---

# %% [markdown]
# ---
#
# ![ChatGPT Image Dec 15, 2025, 12_54_51 AM.png](attachment:16781d80-54f0-4291-917b-2d15fed773ef.png)

# %% [markdown]
# I recently discovered the model, OpenEvidence, by word of mouth from my friend. OpenEvidence prides itself in being a reliable tool for healthcare professionals to provide quick, evidence-based clinical knowledge. Given the particular high spread of misinformation in healthcare, the emergence of an LLM tool such as this could be both an exciting and concerning development as these models have much influence over the thoughts and beliefs of the public. So, with this in mind, I thought it'd be in my best interest to see how reliable the information from OpenEvidence is.
#
# ## Methods
#
# In addition to OpenEvidence, I wanted a point of comparison of its abilities, so I used Gemini 2.5 Flash, a model I tend to use when I have clinical questions. I decided to ask two questions

# %% [markdown]
# ---
#
# ### My Reflection
